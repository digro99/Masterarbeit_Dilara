# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import reciprocal, uniform
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.metrics import roc_curve, roc_auc_score
from imblearn.under_sampling import RandomUnderSampler
import time

# %%
#Dataframe erstellen in dem Ergebnisse gespeichert werden
#Spaltennamen definieren
columns_df = ["Modell", "Accuracy", "Precision", "Recall", "F1-Score", "AUC"]
#Leeren Dataframe erstellen
ergebnisse = pd.DataFrame(columns=columns_df)

# %%
#Daten einlesen
#Datensatz verwenden der mit One Hot Encoding umkodiert wurde
Data = pd.read_csv('/home/RDC/petukhia.hub/H:/petukhia.hub/Masterarbeit_Dilara/LC_Data_Clean.csv',low_memory = False)

# %%
# Aufteilen der Daten in Features (X) und Zielvariable (y)
X = Data.drop('loan_status', axis=1) #Spalte loan Status entfernen
y = Data['loan_status'] #nur Spalte loan staus beibehalten

#Trainings und Test Datensatz erstellen
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.1, random_state = 99)
#10% der Daten als Testdaten beibehalten

# %%
#Daten Scaling da die Spalten unterschiedliche Skalen haben
# Scaler für numerische Variablen initialisieren
scaler = StandardScaler()

###nummerische Trainingsdaten scalen###

#Numerische Variablen auswählen
#nummerische Spaltennamen werden zu einer Liste hinzugefügt
num_cols = ['loan_amnt', 'installment', 'annual_inc', 'dti', 'delinq_2yrs', 'inq_last_6mths', 
            'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'acc_now_delinq', 'tot_coll_amt', 
            'acc_open_past_24mths', 'bc_open_to_buy', 'chargeoff_within_12_mths', 'delinq_amnt', 
            'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 
            'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_inq', 'num_accts_ever_120_pd', 
            'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 
            'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'pct_tl_nvr_dlq', 
            'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 
            'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'fico_average']
numerical_data_train = X_train[num_cols] #kategorische Spalten aus Datensatz entfernen
# Kategorische Variablen auswählen
categorical_data_train = X_train.drop(columns = num_cols) #Kategorische Spalten aus dem Trainingsdatensatz auswählen
# Index des ursprünglichen DataFrame speichern
index_train = numerical_data_train.index
# Scaler auf numerische Trainingsdaten anwenden
scaled_data_train = scaler.fit_transform(numerical_data_train)
# Skalierte numerische Daten in DataFrame zurückkonvertieren
X_train_scaled = pd.DataFrame(scaled_data_train, columns=num_cols, index= index_train)
# Skalierte numerische Daten und kategorische Daten wieder zusammenführen
X_train_scaled = pd.concat([X_train_scaled, categorical_data_train], axis=1)


#nummerische Testdaten scalen 
#Numerische Variablen auswählen
numerical_data_test = X_test[num_cols]
# Kategorische Variablen auswählen
categorical_data_test = X_test.drop(columns = num_cols)
# Index des ursprünglichen DataFrame speichern
index_test = numerical_data_test.index
# Scaler auf numerische Daten anwenden
scaled_data_test = scaler.transform(numerical_data_test) #nicht fit verwenden da auf Trainingsdaten gefittet wurde
# Skalierte numerische Daten in DataFrame zurückkonvertieren
X_test_scaled = pd.DataFrame(scaled_data_test, columns=num_cols, index= index_test)
# Skalierte numerische Daten und kategorische Daten wieder zusammenführen
X_test_scaled = pd.concat([X_test_scaled, categorical_data_test], axis=1)

# %%
#Anzahl an Beobachtungen reduzieren um Rechenzeit zu verringern mittels Undersampling
#Undersampling
print("Vor Undersampling:")
print("Anzahl Fully Paid:", sum(y_train==0)) #Anzahl an Beobachtungen mit "0" zählen
print("Anzahl Charged Off:", sum(y_train==1)) #Anzahl an Beobachtungen mit "1" zählen

# Random Undersampling
rus = RandomUnderSampler(random_state=42) #Algorithmus initialisieren
X_train_res, y_train_res = rus.fit_resample(X_train_scaled, y_train) #undersampler anwenden

#Ausgabe neuer Verteilung
print("\nNach Undersampling:")
print("Anzahl Fully Paid:", sum(y_train_res==0))
print("Anzahl Charged Off:", sum(y_train_res==1))
# Out:
# Vor Undersampling:
# Anzahl Fully Paid: 188592
# Anzahl Charged Off: 45656
#
# Nach Undersampling:
# Anzahl Fully Paid: 45656
# Anzahl Charged Off: 45656

# %%
# Teilmenge erstellen (10% der Daten)
subset_fraction = 0.10
subset_size = int(subset_fraction * len(X_train_res))

# Zufällige Auswahl von 10% der Daten
subset_indices = np.random.choice(len(X_train_res), size=subset_size, replace=False)

# Überprüfen der Verteilung in der Teilmenge
print("\nTeilmenge vor zufälliger Auswahl:")
print("Anzahl Fully Paid:", sum(y_train_res == 0))
print("Anzahl Charged Off:", sum(y_train_res == 1))

# Erstellen des neuen DataFrames
X_train_subset = X_train_res.iloc[subset_indices, :]
y_train_subset = y_train_res.iloc[subset_indices]

# Überprüfen der Verteilung in der Teilmenge
print("\nTeilmenge nach zufälliger Auswahl:")
print("Anzahl Fully Paid:", sum(y_train_subset == 0))
print("Anzahl Charged Off:", sum(y_train_subset == 1))
# Out:
# Teilmenge vor zufälliger Auswahl:
# Anzahl Fully Paid: 45656
# Anzahl Charged Off: 45656
#
# Teilmenge nach zufälliger Auswahl:
# Anzahl Fully Paid: 4521
# Anzahl Charged Off: 4610

# %%
#vorläufige SVM 
svm = SVC(random_state = 42,probability = True) #support vector classifer modell
svm.fit (X_train_res, y_train_res) #Modell an Trainingsdaten fitten

modell = "Scaling + Undersampling"

#Genauigkeit vom Modell testen
accuracy = svm.score(X_test_scaled, y_test)
print(f"Genauigkeit auf den Testdaten: {accuracy}")

#Weitere Testmetriken berechnen

# Vorhersagen für die Testdaten berechnen
y_test_pred = svm.predict(X_test_scaled)
y_scores = svm.predict_proba(X_test_scaled)[:, 1]

#Testdaten
# Berechnung der Precision
precision_test = precision_score(y_test, y_test_pred)
print('Precision: ', precision_test)
# Berechnung des Recall
recall_test = recall_score(y_test, y_test_pred)
print('Recall: ', recall_test)
# Berechnung des F1-Scores
f1_test = f1_score(y_test, y_test_pred)
print('F1: ', f1_test)
#Berechnung AUC
auc = roc_auc_score(y_test, y_scores)
print('AUC: ', auc)

#Ergebnisse zum Dataframe hinzufügen
ergebnisse.loc[0] = [modell, accuracy, precision_test, recall_test, f1_test, auc]
# Out:
# Genauigkeit auf den Testdaten: 0.6444982326725065
# Precision:  0.3098046443051972
# Recall:  0.656
# F1:  0.420854979032359
# AUC:  0.7040630881551604

# %%
# SVM-Modell initialisieren
svm2 = SVC(random_state = 42,probability = True)

#Parameterraum festlegen
param_distributions = {
    'C': uniform (1, 100), #Werte für C müssen > 0 ***Strafterm, uniform macht gleichmäßige kotinuierliche Verteilung
    'gamma': reciprocal(0.001, 0.1), #Breite des Kernels, reciprocal ist Verteilung bei der Logarithmus des Zufallswert gleichmäßig verteilt ist
    'kernel':['linear'] 
}

#RandomizedSearchCV initialisieren
random_search = RandomizedSearchCV(
    svm2, #vorher definiertes Mdoell
    param_distributions=param_distributions, #vorher festgelegte Parameter
    n_iter = 50, #Anzahl an verschiedenen Kombinationen die ausprobiert werden
    verbose = 2, #steuert Detailgrad der Ausgabe der Suche
    cv=3, #3-fache Kreuzvalidierung
    n_jobs = -1 #bestimmt wie viel CPU Kerne für Prozess verwendet werden ( -1 = alle verfügbaren)
)

#RandomSearchCV trainieren
random_search.fit(X_train_subset, y_train_subset)
#SVM trainieren
best_svm2 = random_search.best_estimator_
best_svm2.fit(X_train_res, y_train_res)



#Beste Paramete rund Modell ausgeben
print("Beste Parameter: ", random_search.best_params_)
print("Bester Score: ", random_search.best_score_)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END C=68.23648637416964, gamma=0.006733744415386802, kernel=linear; total time= 9.1min
# [CV] END C=66.63046515227086, gamma=0.0011703736598460855, kernel=linear; total time= 9.2min
# [CV] END C=35.28806269417567, gamma=0.007805972750221887, kernel=linear; total time= 5.4min
# [CV] END C=53.59040484851395, gamma=0.006767336671799449, kernel=linear; total time= 7.5min
# [CV] END C=37.03373271934311, gamma=0.07275618930637028, kernel=linear; total time= 5.6min
# [CV] END C=49.254050728997534, gamma=0.02344110872420641, kernel=linear; total time= 7.0min
# [CV] END C=90.13972067900427, gamma=0.017409755144458104, kernel=linear; total time=11.5min
# [CV] END C=68.23648637416964, gamma=0.006733744415386802, kernel=linear; total time= 9.2min
# [CV] END C=66.63046515227086, gamma=0.0011703736598460855, kernel=linear; total time= 9.3min
# [CV] END C=19.185444648854197, gamma=0.0054567925309495485, kernel=linear; total time= 3.1min
# [CV] END C=22.289736444563058, gamma=0.03890028859028044, kernel=linear; total time= 3.4min
# [CV] END C=4.246789924449756, gamma=0.0023234957235146255, kernel=linear; total time= 1.0min
# [CV] END C=38.75854619124333, gamma=0.005158791997354703, kernel=linear; total time= 5.7min
# [CV] END C=37.03373271934311, gamma=0.07275618930637028, kernel=linear; total time= 5.5min
# [CV] END C=68.94281599153798, gamma=0.003720832472331482, kernel=linear; total time= 9.0min
# [CV] END C=66.63046515227086, gamma=0.0011703736598460855, kernel=linear; total time= 9.6min
# [CV] END C=49.254050728997534, gamma=0.02344110872420641, kernel=linear; total time= 6.9min
# [CV] END C=90.13972067900427, gamma=0.017409755144458104, kernel=linear; total time=11.7min
# [CV] END C=19.185444648854197, gamma=0.0054567925309495485, kernel=linear; total time= 3.0min
# [CV] END C=22.289736444563058, gamma=0.03890028859028044, kernel=linear; total time= 3.4min
# [CV] END C=4.246789924449756, gamma=0.0023234957235146255, kernel=linear; total time=  59.9s
# [CV] END C=38.75854619124333, gamma=0.005158791997354703, kernel=linear; total time= 5.7min
# [CV] END C=37.03373271934311, gamma=0.07275618930637028, kernel=linear; total time= 5.5min
# [CV] END C=68.23648637416964, gamma=0.006733744415386802, kernel=linear; total time= 9.3min
# [CV] END C=67.68124519475258, gamma=0.08217370115476272, kernel=linear; total time= 9.4min
# [CV] END C=6.664782850828242, gamma=0.0015381814072343008, kernel=linear; total time= 1.4min
# [CV] END C=43.27038905901149, gamma=0.0025842162476564655, kernel=linear; total time= 6.4min
# [CV] END C=62.05776388824453, gamma=0.0011997435825819827, kernel=linear; total time= 8.1min
# [CV] END C=17.935793097470373, gamma=0.005864257306542933, kernel=linear; total time= 2.9min
# [CV] END C=17.56672524627173, gamma=0.02931755862987939, kernel=linear; total time= 2.9min
# [CV] END C=3.701756077026485, gamma=0.013149270299405684, kernel=linear; total time=  57.6s
# [CV] END C=97.49908893156845, gamma=0.0434215205785727, kernel=linear; total time=12.2min
# [CV] END C=17.935793097470373, gamma=0.005864257306542933, kernel=linear; total time= 2.7min
# [CV] END C=68.94281599153798, gamma=0.003720832472331482, kernel=linear; total time= 9.6min
# [CV] END C=67.68124519475258, gamma=0.08217370115476272, kernel=linear; total time= 9.2min
# [CV] END C=49.254050728997534, gamma=0.02344110872420641, kernel=linear; total time= 6.9min
# [CV] END C=90.13972067900427, gamma=0.017409755144458104, kernel=linear; total time=11.9min
# [CV] END C=68.94281599153798, gamma=0.003720832472331482, kernel=linear; total time= 9.3min
# [CV] END C=67.68124519475258, gamma=0.08217370115476272, kernel=linear; total time= 9.6min
# [CV] END C=6.664782850828242, gamma=0.0015381814072343008, kernel=linear; total time= 1.4min
# [CV] END C=43.27038905901149, gamma=0.0025842162476564655, kernel=linear; total time= 6.1min
# [CV] END C=62.05776388824453, gamma=0.0011997435825819827, kernel=linear; total time= 8.6min
# [CV] END C=17.935793097470373, gamma=0.005864257306542933, kernel=linear; total time= 2.9min
# [CV] END C=47.49581711769735, gamma=0.0011101312907817605, kernel=linear; total time= 6.8min
# [CV] END C=58.73727026815014, gamma=0.04798040317647612, kernel=linear; total time= 7.9min
# [CV] END C=8.16528864683511, gamma=0.02308925572968448, kernel=linear; total time= 1.5min
# [CV] END C=20.566962465586577, gamma=0.0012496127228334127, kernel=linear; total time= 3.0min
# [CV] END C=17.56672524627173, gamma=0.02931755862987939, kernel=linear; total time= 2.9min
# [CV] END C=3.701756077026485, gamma=0.013149270299405684, kernel=linear; total time=  52.2s
# [CV] END C=97.49908893156845, gamma=0.0434215205785727, kernel=linear; total time=12.4min
# [CV] END C=20.566962465586577, gamma=0.0012496127228334127, kernel=linear; total time= 3.0min
# [CV] END C=47.49581711769735, gamma=0.0011101312907817605, kernel=linear; total time= 6.6min
# [CV] END C=58.73727026815014, gamma=0.04798040317647612, kernel=linear; total time= 8.1min
# [CV] END C=8.16528864683511, gamma=0.02308925572968448, kernel=linear; total time= 1.5min
# [CV] END C=20.566962465586577, gamma=0.0012496127228334127, kernel=linear; total time= 3.1min
# [CV] END C=84.86420800555616, gamma=0.0011207838337067815, kernel=linear; total time=11.5min
# [CV] END C=19.586287713525717, gamma=0.0020976325650899014, kernel=linear; total time= 3.1min
# [CV] END C=8.16528864683511, gamma=0.02308925572968448, kernel=linear; total time= 1.6min
# [CV] END C=20.4310753765333, gamma=0.002139763469537422, kernel=linear; total time= 3.1min
# [CV] END C=3.718301602027484, gamma=0.004409659443147028, kernel=linear; total time=  54.7s
# [CV] END C=70.08737690878466, gamma=0.0013649239397809383, kernel=linear; total time= 9.6min
# [CV] END C=67.44933681250671, gamma=0.038265834319833145, kernel=linear; total time= 8.9min
# [CV] END C=19.185444648854197, gamma=0.0054567925309495485, kernel=linear; total time= 2.9min
# [CV] END C=22.289736444563058, gamma=0.03890028859028044, kernel=linear; total time= 3.5min
# [CV] END C=4.246789924449756, gamma=0.0023234957235146255, kernel=linear; total time=  59.7s
# [CV] END C=62.05776388824453, gamma=0.0011997435825819827, kernel=linear; total time= 8.8min
# [CV] END C=20.4310753765333, gamma=0.002139763469537422, kernel=linear; total time= 3.1min
# [CV] END C=77.52481834456566, gamma=0.037144631956672204, kernel=linear; total time=10.4min
# [CV] END C=67.44933681250671, gamma=0.038265834319833145, kernel=linear; total time= 9.1min
# [CV] END C=6.664782850828242, gamma=0.0015381814072343008, kernel=linear; total time= 1.4min
# [CV] END C=43.27038905901149, gamma=0.0025842162476564655, kernel=linear; total time= 5.8min
# [CV] END C=38.75854619124333, gamma=0.005158791997354703, kernel=linear; total time= 5.5min
# [CV] END C=17.239666461756773, gamma=0.022948667428784812, kernel=linear; total time= 2.7min
# [CV] END C=29.591462395745815, gamma=0.008235676059920606, kernel=linear; total time= 4.1min
# [CV] END C=59.986739833551006, gamma=0.005356563999992216, kernel=linear; total time= 8.2min
# [CV] END C=62.66463079019843, gamma=0.0016043120359625724, kernel=linear; total time= 8.3min
# [CV] END C=20.4310753765333, gamma=0.002139763469537422, kernel=linear; total time= 3.0min
# [CV] END C=35.28806269417567, gamma=0.007805972750221887, kernel=linear; total time= 4.9min
# [CV] END C=53.59040484851395, gamma=0.006767336671799449, kernel=linear; total time= 7.5min
# [CV] END C=17.239666461756773, gamma=0.022948667428784812, kernel=linear; total time= 2.9min
# [CV] END C=29.591462395745815, gamma=0.008235676059920606, kernel=linear; total time= 4.3min
# [CV] END C=77.52481834456566, gamma=0.037144631956672204, kernel=linear; total time=10.4min
# [CV] END C=67.44933681250671, gamma=0.038265834319833145, kernel=linear; total time= 9.3min
# [CV] END C=35.28806269417567, gamma=0.007805972750221887, kernel=linear; total time= 4.9min
# [CV] END C=53.59040484851395, gamma=0.006767336671799449, kernel=linear; total time= 7.6min
# [CV] END C=17.239666461756773, gamma=0.022948667428784812, kernel=linear; total time= 2.8min
# [CV] END C=29.591462395745815, gamma=0.008235676059920606, kernel=linear; total time= 4.5min
# [CV] END C=3.718301602027484, gamma=0.004409659443147028, kernel=linear; total time=  55.5s
# [CV] END C=70.08737690878466, gamma=0.0013649239397809383, kernel=linear; total time= 9.6min
# [CV] END C=87.2309122083276, gamma=0.009984223482185384, kernel=linear; total time=10.8min
# [CV] END C=3.718301602027484, gamma=0.004409659443147028, kernel=linear; total time=  58.5s
# [CV] END C=70.08737690878466, gamma=0.0013649239397809383, kernel=linear; total time= 9.5min
# [CV] END C=87.2309122083276, gamma=0.009984223482185384, kernel=linear; total time=11.1min
# [CV] END C=77.52481834456566, gamma=0.037144631956672204, kernel=linear; total time=10.6min
# [CV] END C=87.2309122083276, gamma=0.009984223482185384, kernel=linear; total time=11.2min
# [CV] END C=80.97360570485996, gamma=0.09462985450391626, kernel=linear; total time=10.7min
# [CV] END C=91.50531615608955, gamma=0.029292077914923345, kernel=linear; total time=11.1min
# [CV] END C=80.97360570485996, gamma=0.09462985450391626, kernel=linear; total time=11.2min
# [CV] END C=91.50531615608955, gamma=0.029292077914923345, kernel=linear; total time=11.3min
# [CV] END C=80.97360570485996, gamma=0.09462985450391626, kernel=linear; total time=10.8min
# [CV] END C=91.50531615608955, gamma=0.029292077914923345, kernel=linear; total time=11.8min
# [CV] END C=92.20451356331964, gamma=0.03622321580695564, kernel=linear; total time=12.3min
# [CV] END C=84.39528518470156, gamma=0.007355186914830017, kernel=linear; total time=10.5min
# [CV] END C=64.87560120577425, gamma=0.001737003567513337, kernel=linear; total time= 8.8min
# [CV] END C=22.157403768921224, gamma=0.002591823617339804, kernel=linear; total time= 3.5min
# [CV] END C=84.39528518470156, gamma=0.007355186914830017, kernel=linear; total time=10.6min
# [CV] END C=1.6034592719239562, gamma=0.011172976682896204, kernel=linear; total time=  36.1s
# [CV] END C=58.7499683095686, gamma=0.0354804458697658, kernel=linear; total time= 8.2min
# [CV] END C=22.157403768921224, gamma=0.002591823617339804, kernel=linear; total time= 3.5min
# [CV] END C=84.39528518470156, gamma=0.007355186914830017, kernel=linear; total time=10.6min
# [CV] END C=84.86420800555616, gamma=0.0011207838337067815, kernel=linear; total time=11.4min
# [CV] END C=19.586287713525717, gamma=0.0020976325650899014, kernel=linear; total time= 3.0min
# [CV] END C=80.96926943835454, gamma=0.0836170085139306, kernel=linear; total time= 9.5min
# [CV] END C=47.49581711769735, gamma=0.0011101312907817605, kernel=linear; total time= 6.7min
# [CV] END C=58.73727026815014, gamma=0.04798040317647612, kernel=linear; total time= 7.9min
# [CV] END C=80.96926943835454, gamma=0.0836170085139306, kernel=linear; total time= 9.5min
# [CV] END C=84.86420800555616, gamma=0.0011207838337067815, kernel=linear; total time=11.5min
# [CV] END C=19.586287713525717, gamma=0.0020976325650899014, kernel=linear; total time= 3.1min
# [CV] END C=80.96926943835454, gamma=0.0836170085139306, kernel=linear; total time= 9.8min
# [CV] END C=59.986739833551006, gamma=0.005356563999992216, kernel=linear; total time= 8.1min
# [CV] END C=62.66463079019843, gamma=0.0016043120359625724, kernel=linear; total time= 8.4min
# [CV] END C=66.60314792689016, gamma=0.013074976565753413, kernel=linear; total time= 7.9min
# [CV] END C=59.986739833551006, gamma=0.005356563999992216, kernel=linear; total time= 8.4min
# [CV] END C=62.66463079019843, gamma=0.0016043120359625724, kernel=linear; total time= 8.2min
# [CV] END C=66.60314792689016, gamma=0.013074976565753413, kernel=linear; total time= 7.9min
# [CV] END C=1.6034592719239562, gamma=0.011172976682896204, kernel=linear; total time=  37.7s
# [CV] END C=58.7499683095686, gamma=0.0354804458697658, kernel=linear; total time= 8.0min
# [CV] END C=61.946474368649476, gamma=0.001906008033221752, kernel=linear; total time= 8.2min
# [CV] END C=66.60314792689016, gamma=0.013074976565753413, kernel=linear; total time= 7.9min
# [CV] END C=92.20451356331964, gamma=0.03622321580695564, kernel=linear; total time=12.0min
# [CV] END C=19.03276834174179, gamma=0.0011258655233753764, kernel=linear; total time= 2.9min
# [CV] END C=84.63258903893221, gamma=0.006002415204452893, kernel=linear; total time= 9.8min
# [CV] END C=1.6034592719239562, gamma=0.011172976682896204, kernel=linear; total time=  35.6s
# [CV] END C=58.7499683095686, gamma=0.0354804458697658, kernel=linear; total time= 8.1min
# [CV] END C=22.157403768921224, gamma=0.002591823617339804, kernel=linear; total time= 3.4min
# [CV] END C=19.03276834174179, gamma=0.0011258655233753764, kernel=linear; total time= 2.9min
# [CV] END C=84.63258903893221, gamma=0.006002415204452893, kernel=linear; total time= 9.9min
# [CV] END C=92.20451356331964, gamma=0.03622321580695564, kernel=linear; total time=11.8min
# [CV] END C=19.03276834174179, gamma=0.0011258655233753764, kernel=linear; total time= 3.2min
# [CV] END C=84.63258903893221, gamma=0.006002415204452893, kernel=linear; total time= 9.9min
# [CV] END C=17.56672524627173, gamma=0.02931755862987939, kernel=linear; total time= 2.8min
# [CV] END C=3.701756077026485, gamma=0.013149270299405684, kernel=linear; total time=  54.2s
# [CV] END C=97.49908893156845, gamma=0.0434215205785727, kernel=linear; total time=13.2min
# [CV] END C=85.2648299903435, gamma=0.008623635565117135, kernel=linear; total time= 9.9min
# [CV] END C=64.87560120577425, gamma=0.001737003567513337, kernel=linear; total time= 8.7min
# [CV] END C=61.946474368649476, gamma=0.001906008033221752, kernel=linear; total time= 8.6min
# [CV] END C=85.2648299903435, gamma=0.008623635565117135, kernel=linear; total time= 9.6min
# [CV] END C=64.87560120577425, gamma=0.001737003567513337, kernel=linear; total time= 8.6min
# [CV] END C=61.946474368649476, gamma=0.001906008033221752, kernel=linear; total time= 8.6min
# [CV] END C=85.2648299903435, gamma=0.008623635565117135, kernel=linear; total time=10.0min
# Beste Parameter:  {'C': 3.718301602027484, 'gamma': 0.004409659443147028, 'kernel': 'linear'}
# Bester Score:  0.6338842124036425

# %%
modell2 = "Scaling + Undersampling +\nHyperparameter"

#Genauigkeit vom Modell testen
accuracy2 = best_svm2.score(X_test_scaled, y_test)
print(f"Genauigkeit auf den Testdaten: {accuracy2}")

#Weitere Testmetriken berechnen

# Vorhersagen für die Testdaten berechnen
y_test_pred2 = best_svm2.predict(X_test_scaled)
y_scores2 = best_svm2.predict_proba(X_test_scaled)[:, 1]

#Testdaten
# Berechnung der Precision
precision_test2 = precision_score(y_test, y_test_pred2)
print('Precision: ', precision_test2)
# Berechnung des Recall
recall_test2 = recall_score(y_test, y_test_pred2)
print('Recall: ', recall_test2)
# Berechnung des F1-Scores
f1_test2 = f1_score(y_test, y_test_pred2)
print('F1: ', f1_test2)
#Berechnung AUC
auc2 = roc_auc_score(y_test, y_scores2)
print('AUC: ', auc2)

#Ergebnisse zum Dataframe hinzufügen
ergebnisse.loc[1] = [modell2, accuracy2, precision_test2, recall_test2, f1_test2, auc2]
# Out:
# Genauigkeit auf den Testdaten: 0.6727370524051022
# Precision:  0.3174825174825175
# Recall:  0.5758048780487804
# F1:  0.4092926490984744
# AUC:  0.6919537515329226

# %% [markdown]
# ## Feature Selection
# Feature reduzieren anhand von Lasso Regression bei LR

# %%
#Nur relevante Features behalten

#relevante Features
features = ['loan_amnt', 'dti', 'acc_open_past_24mths', 'mo_sin_old_rev_tl_op',
       'mort_acc', 'mths_since_recent_inq', 'tot_hi_cred_lim',
       'total_bc_limit', 'fico_average', 'emp_length', 'home_ownership']

X_train_sel = X_train_res[features]
X_test_sel = X_test_scaled[features]

# %%
#SVM mit ausgwählten Features ohne Hyperparameter Optimierung
svm3 = SVC(random_state = 42,probability = True) #support vector classifer modell
svm3.fit (X_train_sel, y_train_res) #Modell an Trainingsdaten fitten
y_test_pred3 = svm3.predict(X_test_sel)#Modell trifft voraussagen
y_scores3 = svm3.predict_proba(X_test_sel)[:, 1]

modell3 = "Scaling + Undersampling +\nFeature Selection"
#Genauigkeit vom Modell testen
accuracy3 = svm3.score(X_test_sel, y_test)
print(f"Genauigkeit auf den Testdaten: {accuracy3}")

#Weitere Testmetriken berechnen

#Testdaten
# Berechnung der Precision
precision_test3 = precision_score(y_test, y_test_pred3)
print('Precision: ', precision_test)
# Berechnung des Recall
recall_test3 = recall_score(y_test, y_test_pred3)
print('Recall: ', recall_test3)
# Berechnung des F1-Scores
f1_test3 = f1_score(y_test, y_test_pred3)
print('F1: ', f1_test3)
#Berechnung AUC
auc3 = roc_auc_score(y_test, y_scores3)
print('AUC: ', auc3)

#Ergebnisse zum Dataframe hinzufügen
ergebnisse.loc[2] = [modell3, accuracy3, precision_test3, recall_test3, f1_test3, auc3]
# Out:
# Genauigkeit auf den Testdaten: 0.594897802366682
# Precision:  0.3098046443051972
# Recall:  0.6565853658536586
# F1:  0.3896028713673729
# AUC:  0.6650722045966094

# %%
# SVM-Modell initialisieren
svm4 = SVC(random_state = 42,probability = True)

#Parameterraum festlegen
param_distributions = {
    'C': uniform (1, 100), #Werte für C müssen > 0 ***Strafterm, uniform macht gleichmäßige kotinuierliche Verteilung
    'gamma': reciprocal(0.001, 0.1), #Breite des Kernels, reciprocal ist Verteilung bei der Logarithmus des Zufallswert gleichmäßig verteilt ist
    'kernel':['linear'] 
}

#RandomizedSearchCV initialisieren
random_search2 = RandomizedSearchCV(
    svm4, #vorher definiertes Mdoell
    param_distributions=param_distributions, #vorher festgelegte Parameter
    n_iter = 50, #Anzahl an verschiedenen Kombinationen die ausprobiert werden
    verbose = 2, #steuert Detailgrad der Ausgabe der Suche
    cv=3, #3-fache Kreuzvalidierung
    n_jobs = -1 #bestimmt wie viel CPU Kerne für Prozess verwendet werden ( -1 = alle verfügbaren)
)

#RandomSearchCV trainieren
random_search2.fit(X_train_subset, y_train_subset)

# Startzeit messen
start_time = time.time()
#SVM trainieren
best_svm4 = random_search2.best_estimator_
best_svm4.fit(X_train_sel, y_train_res)

# Endzeit messen
end_time = time.time()

#Beste Paramete rund Modell ausgeben
print("Beste Parameter: ", random_search2.best_params_)
print("Bester Score: ", random_search2.best_score_)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END C=92.90174154244288, gamma=0.0030733368899166415, kernel=linear; total time=17.0min
# [CV] END C=2.9816348337681866, gamma=0.0011467087802068544, kernel=linear; total time= 1.2min
# [CV] END C=40.785850999186465, gamma=0.027214729453071424, kernel=linear; total time= 7.8min
# [CV] END C=56.28957394444611, gamma=0.002906877760619816, kernel=linear; total time=11.2min
# [CV] END C=12.49365700440006, gamma=0.05882728140380354, kernel=linear; total time= 2.9min
# [CV] END C=50.80538653139174, gamma=0.016496173522944958, kernel=linear; total time= 9.3min
# [CV] END C=10.958870401564045, gamma=0.08682325756182474, kernel=linear; total time= 2.7min
# [CV] END C=89.04259163672288, gamma=0.007269139447024632, kernel=linear; total time=17.0min
# [CV] END C=2.9816348337681866, gamma=0.0011467087802068544, kernel=linear; total time= 1.2min
# [CV] END C=40.785850999186465, gamma=0.027214729453071424, kernel=linear; total time= 8.0min
# [CV] END C=32.04971119892291, gamma=0.017075957286390723, kernel=linear; total time= 6.6min
# [CV] END C=42.75430308468789, gamma=0.027138609774708514, kernel=linear; total time= 8.5min
# [CV] END C=10.320579628650172, gamma=0.013542670582754058, kernel=linear; total time= 3.1min
# [CV] END C=40.785850999186465, gamma=0.027214729453071424, kernel=linear; total time= 8.2min
# [CV] END C=41.50277652667893, gamma=0.0015815251819559825, kernel=linear; total time= 8.2min
# [CV] END C=62.727883075885096, gamma=0.0017678843059874534, kernel=linear; total time=11.3min
# [CV] END C=33.98957020900256, gamma=0.005301630206285955, kernel=linear; total time= 6.9min
# [CV] END C=56.28957394444611, gamma=0.002906877760619816, kernel=linear; total time= 9.9min
# [CV] END C=76.39466936251074, gamma=0.003355293192450777, kernel=linear; total time=14.1min
# [CV] END C=10.958870401564045, gamma=0.08682325756182474, kernel=linear; total time= 2.6min
# [CV] END C=48.50697880625092, gamma=0.006503212766034053, kernel=linear; total time= 8.8min
# [CV] END C=36.79356069923379, gamma=0.007394884234349044, kernel=linear; total time= 7.5min
# [CV] END C=16.733251656313097, gamma=0.023030870893236213, kernel=linear; total time= 3.7min
# [CV] END C=33.98957020900256, gamma=0.005301630206285955, kernel=linear; total time= 6.5min
# [CV] END C=89.04259163672288, gamma=0.007269139447024632, kernel=linear; total time=16.3min
# [CV] END C=16.733251656313097, gamma=0.023030870893236213, kernel=linear; total time= 3.7min
# [CV] END C=33.98957020900256, gamma=0.005301630206285955, kernel=linear; total time= 6.6min
# [CV] END C=57.80394060839995, gamma=0.0814194393560834, kernel=linear; total time=10.9min
# [CV] END C=12.49365700440006, gamma=0.05882728140380354, kernel=linear; total time= 3.3min
# [CV] END C=50.80538653139174, gamma=0.016496173522944958, kernel=linear; total time= 9.8min
# [CV] END C=10.958870401564045, gamma=0.08682325756182474, kernel=linear; total time= 2.7min
# [CV] END C=92.90174154244288, gamma=0.0030733368899166415, kernel=linear; total time=16.1min
# [CV] END C=58.08848024168712, gamma=0.040500608839518996, kernel=linear; total time=10.6min
# [CV] END C=89.04259163672288, gamma=0.007269139447024632, kernel=linear; total time=15.9min
# [CV] END C=58.08848024168712, gamma=0.040500608839518996, kernel=linear; total time=10.9min
# [CV] END C=90.2706632504463, gamma=0.038157914169677835, kernel=linear; total time=16.2min
# [CV] END C=58.08848024168712, gamma=0.040500608839518996, kernel=linear; total time=10.9min
# [CV] END C=90.2706632504463, gamma=0.038157914169677835, kernel=linear; total time=16.5min
# [CV] END C=62.37912992328178, gamma=0.04066485616380427, kernel=linear; total time=11.1min
# [CV] END C=20.389615655728676, gamma=0.024949133509770943, kernel=linear; total time= 4.4min
# [CV] END C=55.26747053735234, gamma=0.04715080868885085, kernel=linear; total time=10.7min
# [CV] END C=72.92263747012696, gamma=0.02371738905078507, kernel=linear; total time=12.6min
# [CV] END C=91.17574035338343, gamma=0.013325404494186972, kernel=linear; total time=16.6min
# [CV] END C=62.37912992328178, gamma=0.04066485616380427, kernel=linear; total time=11.3min
# [CV] END C=34.57175205542847, gamma=0.004159639812075606, kernel=linear; total time= 6.9min
# [CV] END C=42.75430308468789, gamma=0.027138609774708514, kernel=linear; total time= 8.3min
# [CV] END C=72.92263747012696, gamma=0.02371738905078507, kernel=linear; total time=12.7min
# [CV] END C=32.04971119892291, gamma=0.017075957286390723, kernel=linear; total time= 7.0min
# [CV] END C=96.08567516117424, gamma=0.002745400515236792, kernel=linear; total time=17.6min
# [CV] END C=18.78723941427005, gamma=0.030250007492529627, kernel=linear; total time= 3.4min
# [CV] END C=91.17574035338343, gamma=0.013325404494186972, kernel=linear; total time=16.5min
# [CV] END C=62.37912992328178, gamma=0.04066485616380427, kernel=linear; total time=11.7min
# [CV] END C=20.389615655728676, gamma=0.024949133509770943, kernel=linear; total time= 4.6min
# [CV] END C=55.26747053735234, gamma=0.04715080868885085, kernel=linear; total time=10.6min
# [CV] END C=72.92263747012696, gamma=0.02371738905078507, kernel=linear; total time=13.0min
# [CV] END C=34.57175205542847, gamma=0.004159639812075606, kernel=linear; total time= 7.1min
# [CV] END C=96.08567516117424, gamma=0.002745400515236792, kernel=linear; total time=17.7min
# [CV] END C=18.78723941427005, gamma=0.030250007492529627, kernel=linear; total time= 3.5min
# [CV] END C=57.80394060839995, gamma=0.0814194393560834, kernel=linear; total time=11.2min
# [CV] END C=12.49365700440006, gamma=0.05882728140380354, kernel=linear; total time= 3.2min
# [CV] END C=50.80538653139174, gamma=0.016496173522944958, kernel=linear; total time= 9.8min
# [CV] END C=18.78723941427005, gamma=0.030250007492529627, kernel=linear; total time= 4.1min
# [CV] END C=70.06834003586197, gamma=0.007139548283756985, kernel=linear; total time=13.0min
# [CV] END C=92.25364701167153, gamma=0.006025982204370216, kernel=linear; total time=15.9min
# [CV] END C=68.09120318085783, gamma=0.06837858507695632, kernel=linear; total time=12.8min
# [CV] END C=92.25364701167153, gamma=0.006025982204370216, kernel=linear; total time=16.1min
# [CV] END C=25.618938852642604, gamma=0.0968180841166128, kernel=linear; total time= 5.7min
# [CV] END C=37.01834541429819, gamma=0.012655675311162178, kernel=linear; total time= 7.3min
# [CV] END C=92.25364701167153, gamma=0.006025982204370216, kernel=linear; total time=16.5min
# [CV] END C=32.04971119892291, gamma=0.017075957286390723, kernel=linear; total time= 6.5min
# [CV] END C=42.75430308468789, gamma=0.027138609774708514, kernel=linear; total time= 8.5min
# [CV] END C=10.320579628650172, gamma=0.013542670582754058, kernel=linear; total time= 2.7min
# [CV] END C=80.44096348766652, gamma=0.03073630192746161, kernel=linear; total time=13.1min
# [CV] END C=20.389615655728676, gamma=0.024949133509770943, kernel=linear; total time= 4.2min
# [CV] END C=55.26747053735234, gamma=0.04715080868885085, kernel=linear; total time=10.4min
# [CV] END C=10.320579628650172, gamma=0.013542670582754058, kernel=linear; total time= 2.8min
# [CV] END C=80.44096348766652, gamma=0.03073630192746161, kernel=linear; total time=13.5min
# [CV] END C=4.616486978073608, gamma=0.042602556086388604, kernel=linear; total time= 1.7min
# [CV] END C=83.03488568744952, gamma=0.008096932957812986, kernel=linear; total time=15.3min
# [CV] END C=2.9816348337681866, gamma=0.0011467087802068544, kernel=linear; total time= 1.1min
# [CV] END C=80.44096348766652, gamma=0.03073630192746161, kernel=linear; total time=13.0min
# [CV] END C=86.84915032948352, gamma=0.009089825360023647, kernel=linear; total time=15.9min
# [CV] END C=99.11235738877744, gamma=0.005821953205124465, kernel=linear; total time=15.3min
# [CV] END C=86.84915032948352, gamma=0.009089825360023647, kernel=linear; total time=15.5min
# [CV] END C=99.11235738877744, gamma=0.005821953205124465, kernel=linear; total time=16.0min
# [CV] END C=86.84915032948352, gamma=0.009089825360023647, kernel=linear; total time=15.4min
# [CV] END C=99.11235738877744, gamma=0.005821953205124465, kernel=linear; total time=16.2min
# [CV] END C=91.17574035338343, gamma=0.013325404494186972, kernel=linear; total time=17.1min
# [CV] END C=6.667247807739761, gamma=0.0020310289481791414, kernel=linear; total time= 2.0min
# [CV] END C=31.18027391267404, gamma=0.005114655613195211, kernel=linear; total time= 6.2min
# [CV] END C=46.61832018416754, gamma=0.005061312927565515, kernel=linear; total time= 6.7min
# [CV] END C=4.616486978073608, gamma=0.042602556086388604, kernel=linear; total time= 1.6min
# [CV] END C=83.03488568744952, gamma=0.008096932957812986, kernel=linear; total time=15.7min
# [CV] END C=6.667247807739761, gamma=0.0020310289481791414, kernel=linear; total time= 2.0min
# [CV] END C=31.18027391267404, gamma=0.005114655613195211, kernel=linear; total time= 6.4min
# [CV] END C=46.61832018416754, gamma=0.005061312927565515, kernel=linear; total time= 6.5min
# [CV] END C=92.90174154244288, gamma=0.0030733368899166415, kernel=linear; total time=17.2min
# [CV] END C=6.667247807739761, gamma=0.0020310289481791414, kernel=linear; total time= 1.9min
# [CV] END C=31.18027391267404, gamma=0.005114655613195211, kernel=linear; total time= 6.7min
# [CV] END C=46.61832018416754, gamma=0.005061312927565515, kernel=linear; total time= 6.5min
# [CV] END C=90.2706632504463, gamma=0.038157914169677835, kernel=linear; total time=16.8min
# [CV] END C=24.31811348458016, gamma=0.0020720215145293517, kernel=linear; total time= 5.2min
# [CV] END C=71.88522859031288, gamma=0.0026020859857248824, kernel=linear; total time=10.6min
# [CV] END C=68.09120318085783, gamma=0.06837858507695632, kernel=linear; total time=12.4min
# [CV] END C=49.48575807151557, gamma=0.0017262955039766142, kernel=linear; total time= 9.6min
# [CV] END C=71.88522859031288, gamma=0.0026020859857248824, kernel=linear; total time=10.7min
# [CV] END C=70.06834003586197, gamma=0.007139548283756985, kernel=linear; total time=12.5min
# [CV] END C=49.48575807151557, gamma=0.0017262955039766142, kernel=linear; total time= 9.5min
# [CV] END C=71.88522859031288, gamma=0.0026020859857248824, kernel=linear; total time=10.9min
# [CV] END C=4.616486978073608, gamma=0.042602556086388604, kernel=linear; total time= 1.4min
# [CV] END C=83.03488568744952, gamma=0.008096932957812986, kernel=linear; total time=15.3min
# [CV] END C=24.31811348458016, gamma=0.0020720215145293517, kernel=linear; total time= 5.1min
# [CV] END C=78.30933953107451, gamma=0.008905836638135642, kernel=linear; total time=11.4min
# [CV] END C=25.618938852642604, gamma=0.0968180841166128, kernel=linear; total time= 5.6min
# [CV] END C=37.01834541429819, gamma=0.012655675311162178, kernel=linear; total time= 7.4min
# [CV] END C=45.128518111353245, gamma=0.04578591275439777, kernel=linear; total time= 8.5min
# [CV] END C=78.30933953107451, gamma=0.008905836638135642, kernel=linear; total time=11.7min
# [CV] END C=70.06834003586197, gamma=0.007139548283756985, kernel=linear; total time=13.1min
# [CV] END C=45.128518111353245, gamma=0.04578591275439777, kernel=linear; total time= 9.0min
# [CV] END C=79.11594926421674, gamma=0.009306184470377888, kernel=linear; total time=11.0min
# [CV] END C=25.618938852642604, gamma=0.0968180841166128, kernel=linear; total time= 5.5min
# [CV] END C=37.01834541429819, gamma=0.012655675311162178, kernel=linear; total time= 7.5min
# [CV] END C=45.128518111353245, gamma=0.04578591275439777, kernel=linear; total time= 8.7min
# [CV] END C=78.30933953107451, gamma=0.008905836638135642, kernel=linear; total time=11.6min
# [CV] END C=48.50697880625092, gamma=0.006503212766034053, kernel=linear; total time= 9.4min
# [CV] END C=36.79356069923379, gamma=0.007394884234349044, kernel=linear; total time= 7.5min
# [CV] END C=24.31811348458016, gamma=0.0020720215145293517, kernel=linear; total time= 5.8min
# [CV] END C=79.11594926421674, gamma=0.009306184470377888, kernel=linear; total time=10.9min
# [CV] END C=68.09120318085783, gamma=0.06837858507695632, kernel=linear; total time=12.8min
# [CV] END C=49.48575807151557, gamma=0.0017262955039766142, kernel=linear; total time=10.0min
# [CV] END C=79.11594926421674, gamma=0.009306184470377888, kernel=linear; total time=11.3min
# [CV] END C=48.50697880625092, gamma=0.006503212766034053, kernel=linear; total time= 9.3min
# [CV] END C=36.79356069923379, gamma=0.007394884234349044, kernel=linear; total time= 7.1min
# [CV] END C=16.733251656313097, gamma=0.023030870893236213, kernel=linear; total time= 4.0min
# [CV] END C=99.2396849922654, gamma=0.002935512329210264, kernel=linear; total time=13.9min
# [CV] END C=41.50277652667893, gamma=0.0015815251819559825, kernel=linear; total time= 8.4min
# [CV] END C=62.727883075885096, gamma=0.0017678843059874534, kernel=linear; total time=12.1min
# [CV] END C=99.2396849922654, gamma=0.002935512329210264, kernel=linear; total time=13.9min
# [CV] END C=41.50277652667893, gamma=0.0015815251819559825, kernel=linear; total time= 8.0min
# [CV] END C=62.727883075885096, gamma=0.0017678843059874534, kernel=linear; total time=12.2min
# [CV] END C=99.2396849922654, gamma=0.002935512329210264, kernel=linear; total time=14.7min
# [CV] END C=56.28957394444611, gamma=0.002906877760619816, kernel=linear; total time=10.4min
# [CV] END C=76.39466936251074, gamma=0.003355293192450777, kernel=linear; total time=14.5min
# [CV] END C=77.50513301217423, gamma=0.001185148770906136, kernel=linear; total time=10.1min
# [CV] END C=34.57175205542847, gamma=0.004159639812075606, kernel=linear; total time= 7.3min
# [CV] END C=96.08567516117424, gamma=0.002745400515236792, kernel=linear; total time=17.8min
# [CV] END C=77.50513301217423, gamma=0.001185148770906136, kernel=linear; total time=10.0min
# [CV] END C=57.80394060839995, gamma=0.0814194393560834, kernel=linear; total time=10.9min
# [CV] END C=76.39466936251074, gamma=0.003355293192450777, kernel=linear; total time=14.0min
# [CV] END C=77.50513301217423, gamma=0.001185148770906136, kernel=linear; total time=10.4min
# Beste Parameter:  {'C': 68.09120318085783, 'gamma': 0.06837858507695632, 'kernel': 'linear'}
# Bester Score:  0.6338842483895238

# %%
modell4 = "Scaling + Undersampling +\nFeature Selection + Hyperparamter"

#Genauigkeit vom Modell testen
accuracy4 = best_svm4.score(X_test_sel, y_test)
print(f"Genauigkeit auf den Testdaten: {accuracy4}")

#Weitere Testmetriken berechnen

# Vorhersagen für die Testdaten berechnen
y_test_pred4 = best_svm4.predict(X_test_sel)
y_scores4 = best_svm4.predict_proba(X_test_sel)[:, 1]

#Testdaten
# Berechnung der Precision
precision_test4 = precision_score(y_test, y_test_pred4)
print('Precision: ', precision_test4)
# Berechnung des Recall
recall_test4 = recall_score(y_test, y_test_pred4)
print('Recall: ', recall_test4)
# Berechnung des F1-Scores
f1_test4 = f1_score(y_test, y_test_pred4)
print('F1: ', f1_test4)
#Berechnung AUC
auc4 = roc_auc_score(y_test, y_scores4)
print('AUC: ', auc4)

# Gesamtrechenzeit berechnen und ausgeben
elapsed_time = end_time - start_time
print(f"Gesamtrechenzeit: {elapsed_time} Sekunden")

#Ergebnisse zum Dataframe hinzufügen
ergebnisse.loc[3] = [modell4, accuracy4, precision_test4, recall_test4, f1_test4, auc4]
# Out:
# Genauigkeit auf den Testdaten: 0.5963961887198401
# Precision:  0.2739495798319328
# Recall:  0.6360975609756098
# F1:  0.38296622613803233
# AUC:  0.6562709752247023
# Gesamtrechenzeit: 262574.10936164856 Sekunden

# %%
#Confusion Matrix berechnen
cm2 = confusion_matrix(y_test, y_test_pred4, labels=best_svm4.classes_) #confusionmatrix für Testdaten berecnen
disp = ConfusionMatrixDisplay(confusion_matrix=cm2, #Confusion Matrix plotten
                               display_labels=["Fully Paid", "Charged Off"]) #Labels beschriften

disp.plot()
plt.title('Confusion Matrix für eine SVM') #Überschrift festlegen
# Out:
# Text(0.5, 1.0, 'Confusion Matrix für eine SVM')

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_scores4)

print('AUC: ', auc4)

# ROC-Kurve plotten
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='b', lw=2, label=f'ROC curve (AUC = {auc4:.2f})')
plt.plot([0, 1], [0, 1], color='grey', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Kurve für eine SVM')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# AUC:  0.6562709752247023

# %%
# Numerische Spalten auf 5 Nachkommastellen begrenzen
numerical_cols = ergebnisse.select_dtypes(include=['float64']).columns
ergebnisse[numerical_cols] = ergebnisse[numerical_cols].round(5)

# Tabelle erstellen
fig, ax = plt.subplots(figsize=(12, 4))  # Figur und Achsen erstellen
ax.axis('off')  # Achsen ausschalten

# Spaltenbreiten festlegen
col_widths = [0.3] + [0.14 for _ in range(ergebnisse.shape[1] - 1)]

# Tabellendiagramm erstellen
table = ax.table(cellText=ergebnisse.values, colLabels=ergebnisse.columns, cellLoc='center', loc='center', bbox=[0, 0, 1, 1], colWidths=col_widths)

# Überschriften fett drucken
table.auto_set_font_size(False)
table.set_fontsize(10)  # Schriftgröße anpassen, falls gewünscht
for (i, j), cell in table.get_celld().items():
    if i == 0:
        cell.set_text_props(fontweight='bold')  # Überschrift fett drucken

plt.show()

# %% [markdown]
# ## Modell erklären

# %%
#Koeffizienten
svm_coefficients= best_svm4.coef_

feature_names = X_train_sel.columns

for feature, coef in zip(feature_names, svm_coefficients[0]):
    print(f"{feature}: {coef}")
# Out:
# loan_amnt: 0.49847557056727965
# dti: 0.31330886328305496
# acc_open_past_24mths: 0.24344003667283687
# mo_sin_old_rev_tl_op: -0.09299426283905632
# mort_acc: -0.17670277485012775
# mths_since_recent_inq: -0.1988460658076292
# tot_hi_cred_lim: -0.203274691983097
# total_bc_limit: -0.17118376280996017
# fico_average: -0.3235341587351286
# emp_length: -0.005773613462224603
# home_ownership: -0.2421889078177628
